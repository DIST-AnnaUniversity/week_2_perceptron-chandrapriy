# %%
import math
import numpy as np
def perceptron(c,X,d,w,iter,lam):
    for n in range(1,iter):
        print ("Iteration", n)
        print ("--------------")
        for i, x in enumerate(X):
            net = np.dot(X[i],w)
            out = (2/(1+math.exp(-lam*net)))-1
            r = c*(d[i] - out)*(1-(out*out))
            delta_w = 1/2*(r*x)
            w = delta_w+w
            print ("Step ", i, ":", w)
    return w
def test_perceptron(final_out,X,w,lam):
    for i,x in enumerate(X):
        net = np.dot(X[i],w)
        out = (2/(1+math.exp(-lam*net)))-1
        final_out = final_out+[out]
    return final_out
X = np.array([[1,1],[-0.5,1],[3,1],[-2,1],])
new_input = np.array([[7,1],[-7,1],])
print ("Inputs", X)
d = np.array([1,-1,1,-1])
print ("Teacher values", d)
w= ([0,0])
print ("initial values of weights", w)
c = 2.5
iterations = 7
lam=1
print ("Training")
print ("----------")
final_weight = perceptron(c,X,d,w,iterations,lam)
print ("Final sets of weights: ", final_weight)
final_out = []
print ("Testing")
print ("--------")
final_output = test_perceptron(final_out,new_input,final_weight,lam)
print ("Final output: ", final_output)
print ("Original Teacher values", d)
# Out:
# Inputs [[ 1.   1. ]
#  [-0.5  1. ]
#  [ 3.   1. ]
#  [-2.   1. ]]
# Teacher values [ 1 -1  1 -1]
# initial values of weights [0, 0]
# Training
# ----------
# Iteration 1
# --------------
# Step  0 : [1.25 1.25]
# Step  1 : [ 1.98958643 -0.22917287]
# Step  2 : [ 1.98989376 -0.22907043]
# Step  3 : [ 1.99412083 -0.23118396]
# Iteration 2
# --------------
# Step  0 : [ 2.17712491 -0.04817989]
# Step  1 : [ 2.40050025 -0.49493058]
# Step  2 : [ 2.40054495 -0.49491568]
# Step  3 : [ 2.40103979 -0.4951631 ]
# Iteration 3
# --------------
# Step  0 : [ 2.54690963 -0.34929327]
# Step  1 : [ 2.66035831 -0.57619064]
# Step  2 : [ 2.66036939 -0.57618695]
# Step  3 : [ 2.66051917 -0.57626184]
# Iteration 4
# --------------
# Step  0 : [ 2.76938089 -0.46740012]
# Step  1 : [ 2.8488809  -0.62640015]
# Step  2 : [ 2.84888486 -0.62639883]
# Step  3 : [ 2.84894877 -0.62643079]
# Iteration 5
# --------------
# Step  0 : [ 2.93515351 -0.54022606]
# Step  1 : [ 2.99693379 -0.66378663]
# Step  2 : [ 2.99693555 -0.66378604]
# Step  3 : [ 2.9969684  -0.66380247]
# Iteration 6
# --------------
# Step  0 : [ 3.06822613 -0.59254475]
# Step  1 : [ 3.11892689 -0.69394627]
# Step  2 : [ 3.11892779 -0.69394597]
# Step  3 : [ 3.11894679 -0.69395548]
# Final sets of weights:  [ 3.11894679 -0.69395548]
# Testing
# --------
# Final output:  [0.999999998679856, -0.999999999670497]
# Original Teacher values [ 1 -1  1 -1]
