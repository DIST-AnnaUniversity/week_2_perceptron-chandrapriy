# %%
import math
import numpy as np
def perceptron(c,X,d,w,iter,lam):
    for n in range(1,iter):
        print ("Iteration", n)
        print ("--------------")
        for i, x in enumerate(X):
            net = np.dot(X[i],w)
            out = (2/(1+math.exp(-lam*net)))-1
            r = c*(d[i] - out)*(1-(out*out))
            delta_w = 1/2*(r*x)
            w = delta_w+w
            print ("Step ", i, ":", w)
    return w
def test_perceptron(final_out,X,w,lam):
    for i,x in enumerate(X):
        net = np.dot(X[i],w)
        out = (2/(1+math.exp(-lam*net)))-1
        final_out = final_out+[out]
    return final_out
X = np.array([[1,1],[-0.5,1],[3,1],[-2,1],])
new_input = np.array([[7,1],[-7,1],])
print ("Inputs", X)
d = np.array([1,-1,1,-1])
print ("Teacher values", d)
w= ([7,9])
print ("initial values of weights", w)
c = 2.5
iterations = 7
lam=1
print ("Training")
print ("----------")
final_weight = perceptron(c,X,d,w,iterations,lam)
print ("Final sets of weights: ", final_weight)
final_out = []
print ("Testing")
print ("--------")
final_output = test_perceptron(final_out,new_input,final_weight,lam)
print ("Final output: ", final_output)
print ("Original Teacher values", d)
# Out:
# Inputs [[ 1.   1. ]
#  [-0.5  1. ]
#  [ 3.   1. ]
#  [-2.   1. ]]
# Teacher values [ 1 -1  1 -1]
# initial values of weights [7, 9]
# Training
# ----------
# Iteration 1
# --------------
# Step  0 : [7. 9.]
# Step  1 : [7.02018537 8.95962927]
# Step  2 : [7.02018537 8.95962927]
# Step  3 : [7.02094374 8.95925008]
# Iteration 2
# --------------
# Step  0 : [7.02094374 8.95925008]
# Step  1 : [7.04217634 8.91678487]
# Step  2 : [7.04217634 8.91678487]
# Step  3 : [7.0428148  8.91646564]
# Iteration 3
# --------------
# Step  0 : [7.0428148  8.91646564]
# Step  1 : [7.06520333 8.87168858]
# Step  2 : [7.06520333 8.87168858]
# Step  3 : [7.06573619 8.87142215]
# Iteration 4
# --------------
# Step  0 : [7.06573619 8.87142215]
# Step  1 : [7.08940753 8.82407947]
# Step  2 : [7.08940753 8.82407947]
# Step  3 : [7.0898479  8.82385928]
# Iteration 5
# --------------
# Step  0 : [7.0898479  8.82385928]
# Step  1 : [7.1149513  8.77365248]
# Step  2 : [7.1149513  8.77365248]
# Step  3 : [7.11531125 8.77347251]
# Iteration 6
# --------------
# Step  0 : [7.11531125 8.77347251]
# Step  1 : [7.14202372 8.72004758]
# Step  2 : [7.14202372 8.72004758]
# Step  3 : [7.14231426 8.7199023 ]
# Final sets of weights:  [7.14231426 8.7199023 ]
# Testing
# --------
# Final output:  [1.0, -1.0]
# Original Teacher values [ 1 -1  1 -1]
